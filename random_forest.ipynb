# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
stroke_df = pd.read_csv("resources/healthcare-dataset-stroke-data.csv")
stroke_df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
stroke_df['stroke'].value_counts()
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64

# %%
stroke_df = stroke_df.dropna()

# %%
stroke_df = stroke_df.drop_duplicates()

# %%
stroke_df = stroke_df.drop(stroke_df[stroke_df.gender == 'Other'].index)

# %%
stroke_df.drop(['id'], axis=1, inplace=True)

# %%
stroke_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4908 entries, 0 to 5109
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4908 non-null   object
#  1   age                4908 non-null   float64
#  2   hypertension       4908 non-null   int64
#  3   heart_disease      4908 non-null   int64
#  4   ever_married       4908 non-null   object
#  5   work_type          4908 non-null   object
#  6   Residence_type     4908 non-null   object
#  7   avg_glucose_level  4908 non-null   float64
#  8   bmi                4908 non-null   float64
#  9   smoking_status     4908 non-null   object
#  10  stroke             4908 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 460.1+ KB

# %%
stroke_df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
stroke_df['stroke'].value_counts()
# Out:
# stroke
# 0    4699
# 1     209
# Name: count, dtype: int64

# %% [markdown]
# # Balancing, Encoding, Splitting, Scaling  Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE

# %%
# Class count
class_count_0, class_count_1 = stroke_df['stroke'].value_counts()
print(class_count_0)
print(class_count_1)

class_0 = stroke_df[stroke_df['stroke'] == 0]
class_1 = stroke_df[stroke_df['stroke'] == 1]
# Out:
# 4699
# 209

# %%
# Random Undersampling
class_0_under = class_0.sample(class_count_1)
undersampled_df = pd.concat([class_0_under, class_1], axis=0)
print('Random Under Sampling:')
print(undersampled_df['stroke'].value_counts())
# Out:
# Random Under Sampling:
# stroke
# 0    209
# 1    209
# Name: count, dtype: int64

# %%
# Random Oversampling
class_1_over = class_1.sample(class_count_0,replace=True)
oversampled_df = pd.concat([class_1_over, class_0], axis=0)
print('Random Over Sampling:')
print(oversampled_df['stroke'].value_counts())
# Out:
# Random Over Sampling:
# stroke
# 1    4699
# 0    4699
# Name: count, dtype: int64

# %%
oversampled_df.head()
# Out:
#      gender   age  hypertension  heart_disease ever_married      work_type  \
# 18   Female  60.0             0              0           No        Private
# 192    Male  59.0             0              0          Yes  Self-employed
# 203  Female  78.0             0              0          Yes  Self-employed
# 244    Male  57.0             0              0          Yes        Private
# 63   Female  45.0             0              0          Yes        Private
#
#     Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 18           Urban              89.22  37.8     never smoked       1
# 192          Rural             118.03  35.5           smokes       1
# 203          Rural             109.47  30.8     never smoked       1
# 244          Rural              84.96  36.7          Unknown       1
# 63           Rural              93.72  30.2  formerly smoked       1

# %%
balanced_df = pd.get_dummies(oversampled_df, columns=['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status'])
balanced_df
# Out:
#        age  hypertension  heart_disease  avg_glucose_level   bmi  stroke  \
# 18    60.0             0              0              89.22  37.8       1
# 192   59.0             0              0             118.03  35.5       1
# 203   78.0             0              0             109.47  30.8       1
# 244   57.0             0              0              84.96  36.7       1
# 63    45.0             0              0              93.72  30.2       1
# ...    ...           ...            ...                ...   ...     ...
# 5104  13.0             0              0             103.08  18.6       0
# 5106  81.0             0              0             125.20  40.0       0
# 5107  35.0             0              0              82.99  30.6       0
# 5108  51.0             0              0             166.29  25.6       0
# 5109  44.0             0              0              85.28  26.2       0
#
#       gender_Female  gender_Male  ever_married_No  ever_married_Yes  ...  \
# 18             True        False             True             False  ...
# 192           False         True            False              True  ...
# 203            True        False            False              True  ...
# 244           False         True            False              True  ...
# 63             True        False            False              True  ...
# ...             ...          ...              ...               ...  ...
# 5104           True        False             True             False  ...
# 5106           True        False            False              True  ...
# 5107           True        False            False              True  ...
# 5108          False         True            False              True  ...
# 5109           True        False            False              True  ...
#
#       work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 18                     False               True                    False
# 192                    False              False                     True
# 203                    False              False                     True
# 244                    False               True                    False
# 63                     False               True                    False
# ...                      ...                ...                      ...
# 5104                   False              False                    False
# 5106                   False              False                     True
# 5107                   False              False                     True
# 5108                   False               True                    False
# 5109                   False              False                    False
#
#       work_type_children  Residence_type_Rural  Residence_type_Urban  \
# 18                 False                 False                  True
# 192                False                  True                 False
# 203                False                  True                 False
# 244                False                  True                 False
# 63                 False                  True                 False
# ...                  ...                   ...                   ...
# 5104                True                  True                 False
# 5106               False                 False                  True
# 5107               False                  True                 False
# 5108               False                  True                 False
# 5109               False                 False                  True
#
#       smoking_status_Unknown  smoking_status_formerly smoked  \
# 18                     False                           False
# 192                    False                           False
# 203                    False                           False
# 244                     True                           False
# 63                     False                            True
# ...                      ...                             ...
# 5104                    True                           False
# 5106                   False                           False
# 5107                   False                           False
# 5108                   False                            True
# 5109                    True                           False
#
#       smoking_status_never smoked  smoking_status_smokes
# 18                           True                  False
# 192                         False                   True
# 203                          True                  False
# 244                         False                  False
# 63                          False                  False
# ...                           ...                    ...
# 5104                        False                  False
# 5106                         True                  False
# 5107                         True                  False
# 5108                        False                  False
# 5109                        False                  False
#
# [9398 rows x 21 columns]

# %%
balanced_df['stroke'].value_counts()
# Out:
# stroke
# 1    4699
# 0    4699
# Name: count, dtype: int64

# %%
balanced_df.columns
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi',
#        'stroke', 'gender_Female', 'gender_Male', 'ever_married_No',
#        'ever_married_Yes', 'work_type_Govt_job', 'work_type_Never_worked',
#        'work_type_Private', 'work_type_Self-employed', 'work_type_children',
#        'Residence_type_Rural', 'Residence_type_Urban',
#        'smoking_status_Unknown', 'smoking_status_formerly smoked',
#        'smoking_status_never smoked', 'smoking_status_smokes'],
#       dtype='object')

# %%
scaler = StandardScaler()
scaled_num_col = ['age', 'avg_glucose_level', 'bmi']
balanced_df[scaled_num_col] = scaler.fit_transform(balanced_df[scaled_num_col])
balanced_df.head()
# Out:
#           age  hypertension  heart_disease  avg_glucose_level       bmi  \
# 18   0.236858             0              0          -0.535505  1.133198
# 192  0.191811             0              0          -0.016821  0.813333
# 203  1.047703             0              0          -0.170932  0.159695
# 244  0.101717             0              0          -0.612200  0.980219
# 63  -0.438847             0              0          -0.454489  0.076251
#
#      stroke  gender_Female  gender_Male  ever_married_No  ever_married_Yes  \
# 18        1           True        False             True             False
# 192       1          False         True            False              True
# 203       1           True        False            False              True
# 244       1          False         True            False              True
# 63        1           True        False            False              True
#
#      ...  work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 18   ...                   False               True                    False
# 192  ...                   False              False                     True
# 203  ...                   False              False                     True
# 244  ...                   False               True                    False
# 63   ...                   False               True                    False
#
#      work_type_children  Residence_type_Rural  Residence_type_Urban  \
# 18                False                 False                  True
# 192               False                  True                 False
# 203               False                  True                 False
# 244               False                  True                 False
# 63                False                  True                 False
#
#      smoking_status_Unknown  smoking_status_formerly smoked  \
# 18                    False                           False
# 192                   False                           False
# 203                   False                           False
# 244                    True                           False
# 63                    False                            True
#
#      smoking_status_never smoked  smoking_status_smokes
# 18                          True                  False
# 192                        False                   True
# 203                         True                  False
# 244                        False                  False
# 63                         False                  False
#
# [5 rows x 21 columns]

# %%
X = balanced_df.drop(columns='stroke')
y =  balanced_df['stroke']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
X_train.shape
# Out:
# (7048, 20)

# %%
st = SMOTE()
X_train_resampled, y_train_resampled = st.fit_resample(X_train, y_train)
X_train_resampled.shape, y_train_resampled.value_counts()
# Out:
# ((7048, 20),
#  stroke
#  0    3524
#  1    3524
#  Name: count, dtype: int64)

# %% [markdown]
# # Machine Learning Models

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline

# %% [markdown]
# ## Random Forest

# %%
# Train Random Forest Model
rf_model = RandomForestClassifier(n_estimators=800, random_state=1)
rf_model = rf_model.fit(X_train_resampled, y_train_resampled)
rf_model
# Out:
# RandomForestClassifier(n_estimators=800, random_state=1)

# %%
# Make predictions 
rf_predictions = rf_model.predict(X_test)
rf_predictions
# Out:
# array([1, 1, 1, ..., 1, 0, 0])

# %%
# Evaluate Model
cm = confusion_matrix(y_test, rf_predictions)
cm_df = pd.DataFrame(
    cm, index=['Actual No Stroke', "Actual Stroke"], columns = ['Predicted No Stroke', 'Predicted Stroke']
)
rf_acc_score = accuracy_score(y_test,rf_predictions)
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {rf_acc_score}")
print("Classification Report")
print(classification_report(y_test, rf_predictions))
# Out:
# Confusion Matrix
#                   Predicted No Stroke  Predicted Stroke
# Actual No Stroke                 1147                28
# Actual Stroke                       0              1175
# Accuracy Score : 0.9880851063829788
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      1175
#            1       0.98      1.00      0.99      1175
#
#     accuracy                           0.99      2350
#    macro avg       0.99      0.99      0.99      2350
# weighted avg       0.99      0.99      0.99      2350

# %%
importances = rf_model.feature_importances_
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.3624432036606468, 'age'),
#  (0.20162943201820824, 'avg_glucose_level'),
#  (0.16352521686245763, 'bmi'),
#  (0.038647733279582264, 'hypertension'),
#  (0.022804147209092216, 'ever_married_Yes'),
#  (0.022096637403638937, 'ever_married_No'),
#  (0.019679458738647848, 'heart_disease'),
#  (0.017952605387469595, 'smoking_status_never smoked'),
#  (0.01586061632308517, 'work_type_Self-employed'),
#  (0.015284128003542475, 'smoking_status_Unknown'),
#  (0.014708147442703653, 'Residence_type_Rural'),
#  (0.014506557420078831, 'Residence_type_Urban'),
#  (0.014475285175310852, 'work_type_Private'),
#  (0.013924829182627952, 'smoking_status_formerly smoked'),
#  (0.013320996429546615, 'smoking_status_smokes'),
#  (0.013145860881575742, 'gender_Male'),
#  (0.012970263380422122, 'gender_Female'),
#  (0.01179856501414177, 'work_type_Govt_job'),
#  (0.011114501419967856, 'work_type_children'),
#  (0.00011181476725339985, 'work_type_Never_worked')]

# %%
import pickle
with open('model.pkl','wb') as f:
  pickle.dump(rf_model,f)
